# %%
# !pip install faiss_cpu==1.7.3

# %%
# !pip install matplotlib==3.5.2
# Out:
# ...
#   Using cached matplotlib-3.5.2-cp310-cp310-win_amd64.whl (7.2 MB)
# ...

# %%
pip install numpy==1.24.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas==1.4.3
# Out:
# ...
#   Using cached pandas-1.4.3-cp310-cp310-win_amd64.whl (10.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Pillow==9.5.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install timm==0.6.13
# Out:
# ...
#   Using cached timm-0.6.13-py3-none-any.whl (549 kB)
# ...
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/59/af/426c2b90f5c4f8aba778746465af9e662680570e950e02379e91c6138285/torchvision-0.16.0-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for huggingface-hub from https://files.pythonhosted.org/packages/aa/f3/3fc97336a0e90516901befd4f500f08d691034d387406fdbde85bea827cc/huggingface_hub-0.17.3-py3-none-any.whl.metadata
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# ...
#   Obtaining dependency information for torch>=1.7 from https://files.pythonhosted.org/packages/fa/47/1a7daf04f40715fc1cdc6f1cc3200228a556d06c843e6ceb58883b745e1b/torch-2.1.0-cp310-cp310-win_amd64.whl.metadata
# ...
# Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.2/1.3 MB 5.9 MB/s eta 0:00:01
# ...

# %%
pip install torch==2.0.0
# Out:
# ...
#   Using cached torch-2.0.0-cp310-cp310-win_amd64.whl (172.3 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0
#     Uninstalling torch-2.1.0:
#       Successfully uninstalled torch-2.1.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.16.0 requires torch==2.1.0, but you have torch 2.0.0 which is incompatible.

# %%
pip install torchvision==0.15.1
# Out:
# ...
#   Using cached torchvision-0.15.1-cp310-cp310-win_amd64.whl (1.2 MB)
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.0
#     Uninstalling torchvision-0.16.0:
#       Successfully uninstalled torchvision-0.16.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip intall tqdm==4.65.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "intall" - maybe you meant "install"

# %%
pip install DeepImageSearch --upgrade
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for DeepImageSearch: filename=DeepImageSearch-2.5-py3-none-any.whl size=8485 sha256=370ec285a5b64f756f1329d1975e036811220af3306b4c5afa47e2516477489f
#   Stored in directory: c:\users\m_huzaifa\appdata\local\pip\cache\wheels\50\e6\4e\3c57c420e1fa20cba29a168f084e77129b0299c7fd6cdd08b5
# Successfully built DeepImageSearch
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from DeepImageSearch import Load_Data, Search_Setup

# %%
image_list = Load_Data().from_folder(['animals'])

# %%
import timm
timm.list_models(pretrained=True)
# Out:
# ['adv_inception_v3',
#  'bat_resnext26ts',
#  'beit_base_patch16_224',
#  'beit_base_patch16_224_in22k',
#  'beit_base_patch16_384',
#  'beit_large_patch16_224',
#  'beit_large_patch16_224_in22k',
#  'beit_large_patch16_384',
#  'beit_large_patch16_512',
#  'beitv2_base_patch16_224',
#  'beitv2_base_patch16_224_in22k',
#  'beitv2_large_patch16_224',
#  'beitv2_large_patch16_224_in22k',
#  'botnet26t_256',
#  'cait_m36_384',
#  'cait_m48_448',
#  'cait_s24_224',
#  'cait_s24_384',
#  'cait_s36_384',
#  'cait_xs24_384',
#  'cait_xxs24_224',
#  'cait_xxs24_384',
#  'cait_xxs36_224',
#  'cait_xxs36_384',
#  'coat_lite_mini',
#  'coat_lite_small',
#  'coat_lite_tiny',
#  'coat_mini',
#  'coat_tiny',
#  'coatnet_0_rw_224',
#  'coatnet_1_rw_224',
#  'coatnet_bn_0_rw_224',
#  'coatnet_nano_rw_224',
#  'coatnet_rmlp_1_rw_224',
#  'coatnet_rmlp_2_rw_224',
#  'coatnet_rmlp_nano_rw_224',
#  'coatnext_nano_rw_224',
#  'convit_base',
#  'convit_small',
#  'convit_tiny',
#  'convmixer_768_32',
# ...

# %%
st = Search_Setup(image_list, model_name="vgg19", pretrained=True, image_count=None)
# Out:
#  Please Wait Model Is Loading or Downloading From Server!
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to C:\Users\M_HuzaiFa/.cache\torch\hub\checkpoints\vgg19-dcbb9e9d.pth
#  Model Loaded Successfully: vgg19

# %%
st.run_index()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5358/5358 [1:54:00<00:00,  1.28s/it]
#  Image Meta Information Saved: [metadata-files/vgg19/image_data_features.pkl]
#  Saved The Indexed File:[metadata-files/vgg19/image_features_vectors.idx]

# %%
metadata = st.get_image_metadata_file()

# %%
image_path = ['3cf13ad980.jpg', '7cf6c0e8c0.jpg']
st.add_images_to_index(image_path)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:02<00:00,  1.01s/it]
#  New images added to the index: 2

# %%
st.get_similar_images(image_path='animals/cat/00357563a7.jpg', number_of_images=10)
# Out:
# {498: 'animals\\cat\\00357563a7.jpg',
#  500: 'animals\\cat\\057e6db146.jpg',
#  532: 'animals\\cat\\636b432421.jpg',
#  517: 'animals\\cat\\34fb30ecc5.jpg',
#  4085: 'animals\\rat\\7b0499114b.jpg',
#  4097: 'animals\\rat\\9f1a82530f.jpg',
#  512: 'animals\\cat\\2a40de8365.jpg',
#  509: 'animals\\cat\\15b23c04b7.jpg',
#  555: 'animals\\cat\\9d21019336.jpg',
#  542: 'animals\\cat\\730d6a8791.jpg'}

# %%
st.plot_similar_images(image_path='animals/cat/00357563a7.jpg', number_of_images=9)

# %%
# dataset link
### https://www.kaggle.com/datasets/iamsouravbanerjee/animal-image-dataset-90-different-animals
